# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("dftRoadSafetyData_Accidents_2018.csv")
# Out:
# /home/aesthetixell/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  2018010080971               529150.0                182270.0  -0.139737
# 1  2018010080973               542020.0                184290.0   0.046471
# 2  2018010080974               531720.0                182910.0  -0.102474
# 3  2018010080981               541450.0                183220.0   0.037828
# 4  2018010080982               543580.0                176500.0   0.065781
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.524587             1                  3                   2
# 1  51.539651             1                  3                   1
# 2  51.529746             1                  3                   2
# 3  51.530179             1                  2                   2
# 4  51.469258             1                  2                   2
#
#    Number_of_Casualties        Date  ...  Pedestrian_Crossing-Human_Control  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122635 entries, 0 to 122634
# Data columns (total 32 columns):
# Accident_Index                                 122635 non-null object
# Location_Easting_OSGR                          122580 non-null float64
# Location_Northing_OSGR                         122580 non-null float64
# Longitude                                      122580 non-null float64
# Latitude                                       122580 non-null float64
# Police_Force                                   122635 non-null int64
# Accident_Severity                              122635 non-null int64
# Number_of_Vehicles                             122635 non-null int64
# Number_of_Casualties                           122635 non-null int64
# Date                                           122635 non-null object
# Day_of_Week                                    122635 non-null int64
# Time                                           122622 non-null object
# ...

# %%
plt.scatter(data.Longitude,data.Latitude,c = data.Police_Force)

# %%
plt.scatter(data.Longitude,data.Latitude,c = data.Accident_Severity)

# %%
acc_count = data.groupby(data.Accident_Severity).Accident_Severity.count().plot(kind = 'bar')

# %%
acc_count = data.groupby(data.Light_Conditions).Accident_Severity.count().plot(kind = 'bar')

# %%
acc_count = data.groupby(data.Road_Surface_Conditions).Accident_Severity.count().plot(kind = 'bar')

# %%
data
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2018010080971               529150.0                182270.0
# 1       2018010080973               542020.0                184290.0
# 2       2018010080974               531720.0                182910.0
# 3       2018010080981               541450.0                183220.0
# 4       2018010080982               543580.0                176500.0
# ...               ...                    ...                     ...
# 122630  2018984115718               307124.0                594145.0
# 122631  2018984115918               313325.0                581065.0
# 122632  2018984116018               319337.0                574511.0
# 122633  2018984116318               318858.0                566932.0
# 122634  2018984116418               316008.0                568771.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.139737  51.524587             1                  3
# ...

# %%
data = data.drop('LSOA_of_Accident_Location' , axis = 1)
data = data.drop('Did_Police_Officer_Attend_Scene_of_Accident' , axis = 1)
data = data.drop('Carriageway_Hazards' , axis = 1)
data = data.drop('Special_Conditions_at_Site' , axis = 1)
# data = data.drop('Road_Surface_Conditions' , axis = 1)
# data = data.drop('Weather_Conditions' , axis = 1)
# data = data.drop('Light_Conditions' , axis = 1)
data = data.drop('Pedestrian_Crossing-Physical_Facilities' , axis = 1)
data = data.drop('Pedestrian_Crossing-Human_Control' , axis = 1)
data = data.drop('2nd_Road_Number' , axis = 1)
data = data.drop('1st_Road_Class' , axis = 1)
data = data.drop('1st_Road_Number' , axis = 1)
data = data.drop('Junction_Detail' , axis = 1)
data = data.drop('Junction_Control' , axis = 1)
data = data.drop('2nd_Road_Class' , axis = 1)
data = data.drop('Local_Authority_(Highway)' , axis = 1)
data = data.drop('Accident_Index' , axis = 1)
data = data.drop('Date' , axis = 1)
data = data.drop('Time' , axis = 1)

# %%
data.head()
# Out:
#    Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0               529150.0                182270.0  -0.139737  51.524587
# 1               542020.0                184290.0   0.046471  51.539651
# 2               531720.0                182910.0  -0.102474  51.529746
# 3               541450.0                183220.0   0.037828  51.530179
# 4               543580.0                176500.0   0.065781  51.469258
#
#    Police_Force  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0             1                  3                   2                     2
# 1             1                  3                   1                     1
# 2             1                  3                   2                     1
# 3             1                  2                   2                     1
# 4             1                  2                   2                     2
#
#    Day_of_Week  Local_Authority_(District)  Road_Type  Speed_limit  \
# ...

# %%
data = data.drop('Location_Easting_OSGR' , axis = 1)
data = data.drop('Location_Northing_OSGR' , axis = 1)

# %%
import numpy as np; np.random.seed(42)
corr = data.corr()

# %%
# uniform_data = np.random.rand(corr)
ax = sns.heatmap(corr)

# %%
data.head()
# Out:
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -0.139737  51.524587             1                  3                   2
# 1   0.046471  51.539651             1                  3                   1
# 2  -0.102474  51.529746             1                  3                   2
# 3   0.037828  51.530179             1                  2                   2
# 4   0.065781  51.469258             1                  2                   2
#
#    Number_of_Casualties  Day_of_Week  Local_Authority_(District)  Road_Type  \
# 0                     2            2                           2          3
# 1                     1            2                          17          6
# 2                     1            2                           3          6
# 3                     1            2                          17          3
# 4                     2            2                           6          6
#
# ...

# %%
data.apply(lambda x : sum(x.isnull()) , axis = 0)
# Out:
# Longitude                     55
# Latitude                      55
# Police_Force                   0
# Accident_Severity              0
# Number_of_Vehicles             0
# Number_of_Casualties           0
# Day_of_Week                    0
# Local_Authority_(District)     0
# Road_Type                      0
# Speed_limit                    0
# Light_Conditions               0
# Weather_Conditions             0
# Road_Surface_Conditions        0
# Urban_or_Rural_Area            0
# dtype: int64

# %%
data=data.dropna()

# %%
data.apply(lambda x : sum(x.isnull()) , axis = 0)
# Out:
# Longitude                     0
# Latitude                      0
# Police_Force                  0
# Accident_Severity             0
# Number_of_Vehicles            0
# Number_of_Casualties          0
# Day_of_Week                   0
# Local_Authority_(District)    0
# Road_Type                     0
# Speed_limit                   0
# Light_Conditions              0
# Weather_Conditions            0
# Road_Surface_Conditions       0
# Urban_or_Rural_Area           0
# dtype: int64

# %%
data['Local_Authority_(District)'] = (data['Local_Authority_(District)'].max()-data['Local_Authority_(District)'])/(data['Local_Authority_(District)'].max()-data['Police_Force'].min())

# %%
data['Police_Force'] = (data['Police_Force'].max()-data['Police_Force'])/(data['Police_Force'].max()-data['Police_Force'].min())

# %%
data['Local_Police'] = (data['Police_Force'] + data['Local_Authority_(District)']) / 2

# %%
data.head()
# Out:
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -0.139737  51.524587           1.0                  3                   2
# 1   0.046471  51.539651           1.0                  3                   1
# 2  -0.102474  51.529746           1.0                  3                   2
# 3   0.037828  51.530179           1.0                  2                   2
# 4   0.065781  51.469258           1.0                  2                   2
#
#    Number_of_Casualties  Day_of_Week  Local_Authority_(District)  Road_Type  \
# 0                     2            2                    0.998936          3
# 1                     1            2                    0.982979          6
# 2                     1            2                    0.997872          6
# 3                     1            2                    0.982979          3
# 4                     2            2                    0.994681          6
#
# ...

# %%
x = data.drop(columns = ['Accident_Severity'])

# %%
x
# Out:
#         Longitude   Latitude  Police_Force  Number_of_Vehicles  \
# 0       -0.139737  51.524587           1.0                   2
# 1        0.046471  51.539651           1.0                   1
# 2       -0.102474  51.529746           1.0                   2
# 3        0.037828  51.530179           1.0                   2
# 4        0.065781  51.469258           1.0                   2
# ...           ...        ...           ...                 ...
# 122630  -3.461918  55.232746           0.0                   2
# 122631  -3.360440  55.116374           0.0                   2
# 122632  -3.264352  55.058510           0.0                   3
# 122633  -3.269695  54.990344           0.0                   1
# 122634  -3.314764  55.006392           0.0                   1
#
#         Number_of_Casualties  Day_of_Week  Local_Authority_(District)  \
# 0                          2            2                    0.998936
# ...

# %%
y = data.iloc[ : , 4 ]

# %%
y
# Out:
# 0         2
# 1         1
# 2         2
# 3         2
# 4         2
#          ..
# 122630    2
# 122631    2
# 122632    3
# 122633    1
# 122634    1
# Name: Number_of_Vehicles, Length: 122580, dtype: int64

# %%
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f56205002e60> in <module>
# ----> 1 y_train
#
# NameError: name 'y_train' is not defined

# %%
from sklearn.model_selection import train_test_split
x_Train, x_Test, y_Train, y_Test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_Train
# Out:
#         Longitude   Latitude  Police_Force  Number_of_Vehicles  \
# 101035  -0.100055  50.991196      0.525773                   3
# 90608   -0.037682  51.188925      0.546392                   1
# 59885   -2.198511  52.212728      0.783505                   2
# 20793   -0.049521  51.476718      1.000000                   1
# 16995   -0.434252  51.448765      1.000000                   2
# ...           ...        ...           ...                 ...
# 45909   -1.572375  53.761755      0.876289                   2
# 117998  -3.178782  55.962990      0.030928                   2
# 42625   -1.097061  53.953787      0.886598                   2
# 43585   -1.841947  53.645396      0.876289                   2
# 68291    0.174937  52.772811      0.680412                   1
#
#         Number_of_Casualties  Day_of_Week  Local_Authority_(District)  \
# 101035                     1            3                    0.402128
# ...

# %%
x_Test
# Out:
#         Longitude   Latitude  Police_Force  Number_of_Vehicles  \
# 81479    0.481276  51.519820      0.577320                   2
# 50542   -0.650396  53.567176      0.845361                   2
# 90641   -0.619322  51.266306      0.546392                   1
# 100460   0.702543  50.921145      0.525773                   1
# 105417  -3.589081  50.428699      0.494845                   2
# ...           ...        ...           ...                 ...
# 78552   -0.205768  51.805926      0.587629                   2
# 52866   -1.790109  52.503075      0.804124                   2
# 18251   -0.214451  51.464598      1.000000                   1
# 39010   -1.689014  55.542448      0.907216                   2
# 9387     0.217149  51.615418      1.000000                   1
#
#         Number_of_Casualties  Day_of_Week  Local_Authority_(District)  \
# 81479                      1            7                    0.509574
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_Train
# Out:
#         Longitude   Latitude  Police_Force  Number_of_Vehicles  \
# 101035  -0.100055  50.991196      0.525773                   3
# 90608   -0.037682  51.188925      0.546392                   1
# 59885   -2.198511  52.212728      0.783505                   2
# 20793   -0.049521  51.476718      1.000000                   1
# 16995   -0.434252  51.448765      1.000000                   2
# ...           ...        ...           ...                 ...
# 45909   -1.572375  53.761755      0.876289                   2
# 117998  -3.178782  55.962990      0.030928                   2
# 42625   -1.097061  53.953787      0.886598                   2
# 43585   -1.841947  53.645396      0.876289                   2
# 68291    0.174937  52.772811      0.680412                   1
#
#         Number_of_Casualties  Day_of_Week  Local_Authority_(District)  \
# 101035                     1            3                    0.402128
# ...

# %%
clf = LogisticRegression().fit(x_Train, y_Train)
# Out:
# /home/aesthetixell/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/aesthetixell/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
clf
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_Train, y_Train)
# Out:
# /home/aesthetixell/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/aesthetixell/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = classifier.predict(x_Test)

# %%
# Measuring Accuracy
from sklearn import metrics
print('The accuracy of Logistic Regression is: ', metrics.accuracy_score(y_pred, y_Test))
# Out:
# The accuracy of Logistic Regression is:  0.895741556534508

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_Train, y_Train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred = classifier.predict(x_Test)
y_pred.shape
# Out:
# (24516,)

# %%
y_Test.shape
# Out:
# (24516,)

# %%
# Measuring Accuracy
from sklearn import metrics
print('The accuracy of Random Forest Classification is: ', metrics.accuracy_score(y_pred, y_Test))
# Out:
# The accuracy of Random Forest Classification is:  0.996084189916789
