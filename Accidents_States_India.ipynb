# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
import pandas as pd
import numpy as np

# Visualization packages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/My Drive/datafile.xls", encoding="utf-8")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df
# Out:
#                      States/UTs      2003      2004  ...    2014    2015    2016
# 0                Andhra Pradesh   34826.0   38940.0  ...   24440   24258   24888
# 1             Arunachal Pradesh     245.0     241.0  ...     205     284     249
# 2                         Assam    3262.0    3688.0  ...    7144    6959    7435
# 3                         Bihar    6141.0    4027.0  ...    9556    9555    8222
# 4                  Chhattisgarh   10521.0   10600.0  ...   13821   14446   13580
# 5                           Goa    3244.0    3525.0  ...    4229    4338    4304
# 6                       Gujarat   30604.0   30630.0  ...   23712   23183   21859
# 7                       Haryana    8690.0    9321.0  ...   10676   11174   11234
# 8              Himachal Pradesh    2680.0    2808.0  ...    3058    3010    3168
# 9               Jammu & Kashmir    5904.0    6257.0  ...    5861    5836    5501
# 10                    Jharkhand    4211.0    4614.0  ...    5201    5162    4932
# ...

# %%
df.fillna(0)
# Out:
#                      States/UTs      2003      2004  ...    2014    2015    2016
# 0                Andhra Pradesh   34826.0   38940.0  ...   24440   24258   24888
# 1             Arunachal Pradesh     245.0     241.0  ...     205     284     249
# 2                         Assam    3262.0    3688.0  ...    7144    6959    7435
# 3                         Bihar    6141.0    4027.0  ...    9556    9555    8222
# 4                  Chhattisgarh   10521.0   10600.0  ...   13821   14446   13580
# 5                           Goa    3244.0    3525.0  ...    4229    4338    4304
# 6                       Gujarat   30604.0   30630.0  ...   23712   23183   21859
# 7                       Haryana    8690.0    9321.0  ...   10676   11174   11234
# 8              Himachal Pradesh    2680.0    2808.0  ...    3058    3010    3168
# 9               Jammu & Kashmir    5904.0    6257.0  ...    5861    5836    5501
# 10                    Jharkhand    4211.0    4614.0  ...    5201    5162    4932
# ...

# %%
df.mean()
# Out:
# 2003    22595.888889
# 2004    23883.888889
# 2005    24403.055556
# 2006    25606.666667
# 2007    26623.111111
# 2008    26928.000000
# 2009    27021.333333
# 2010    27757.111111
# 2011    28439.200000
# 2012    27243.500000
# 2013    27026.444444
# 2014    26454.054054
# 2015    27103.945946
# 2016    25981.189189
# dtype: float64

# %%
df = df.drop([36])

# %%
df.plot(figsize=(10,10))

# %%
df.groupby('States/UTs').sum()[2003].plot(figsize=(15,12),title="Year wise accidents frequency")

# %%
maharashtra = df.loc[df['States/UTs'] == 'Maharashtra']
maharashtra
# Out:
#      States/UTs     2003     2004     2005  ...     2013   2014   2015   2016
# 14  Maharashtra  65686.0  67720.0  72408.0  ...  63019.0  61627  63805  39878
#
# [1 rows x 15 columns]

# %%
tamil_nadu = df.loc[df['States/UTs'] == 'Tamil Nadu']
tamil_nadu
# Out:
#     States/UTs     2003     2004     2005  ...     2013   2014   2015   2016
# 23  Tamil Nadu  51025.0  52508.0  53866.0  ...  66238.0  67250  69059  71431
#
# [1 rows x 15 columns]

# %%
maharashtra = maharashtra.set_index('States/UTs')

# %%
maharashtra = maharashtra.T

# %%
maharashtra = maharashtra.reset_index()

# %%
maharashtra
# Out:
# States/UTs  index  Maharashtra
# 0            2003      65686.0
# 1            2004      67720.0
# 2            2005      72408.0
# 3            2006      75413.0
# 4            2007      73661.0
# 5            2008      75527.0
# 6            2009      71996.0
# 7            2010      71289.0
# 8            2011      68438.0
# 9            2012      66316.0
# 10           2013      63019.0
# 11           2014      61627.0
# 12           2015      63805.0
# 13           2016      39878.0

# %%
sns.barplot(x="index", y="Maharashtra", data=maharashtra)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
df = df[[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]]

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2)

# %%
X = df.drop([2016],axis=1)
X = X.fillna(0)
X
# Out:
#        2003     2004     2005     2006  ...     2012     2013   2014   2015
# 0   34826.0  38940.0  37131.0  43559.0  ...  42524.0  43482.0  24440  24258
# 1     245.0    241.0    231.0    250.0  ...    251.0    308.0    205    284
# 2    3262.0   3688.0   4258.0   4694.0  ...   6535.0   7211.0   7144   6959
# 3    6141.0   4027.0   3768.0   5594.0  ...  10320.0  10200.0   9556   9555
# 4   10521.0  10600.0  11164.0  11934.0  ...  13511.0  13657.0  13821  14446
# 5    3244.0   3525.0   3577.0   3707.0  ...   4312.0   4294.0   4229   4338
# 6   30604.0  30630.0  30515.0  31547.0  ...  27949.0  25391.0  23712  23183
# 7    8690.0   9321.0   9298.0  10314.0  ...  10065.0  10482.0  10676  11174
# 8    2680.0   2808.0   2797.0   2727.0  ...   2899.0   2981.0   3058   3010
# 9    5904.0   6257.0   5664.0   5593.0  ...   6709.0   6457.0   5861   5836
# 10   4211.0   4614.0   5013.0   4980.0  ...   5711.0   5569.0   5201   5162
# ...

# %%
y = df.drop([2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],axis=1)
y.fillna(0)
y
# Out:
#      2016
# 0   24888
# 1     249
# 2    7435
# 3    8222
# 4   13580
# 5    4304
# 6   21859
# 7   11234
# 8    3168
# 9    5501
# 10   4932
# 11  44403
# 12  39420
# 13  53972
# 14  39878
# 15    538
# 16    620
# 17     83
# 18     75
# 19  10532
# 20   6952
# 21  23066
# 22    210
# 23  71431
# 24  22811
# 25    557
# 26   1591
# 27  35612
# 28  13580
# 29    238
# 30    428
# 31     70
# 32     71
# 33   7375
# 34      1
# 35   1766

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = regressor.predict(X_test)

# %%
pred
# Out:
# array([[ 1213.48023729],
#        [52638.48331649],
#        [ 1554.9574027 ],
#        [  551.1884419 ],
#        [  112.22090082],
#        [  418.48356554],
#        [16932.36061134],
#        [35772.06428858],
#        [ 2249.40731112],
#        [  242.0228911 ],
#        [ 5877.99795506],
#        [  281.60680325]])

# %%
y_test
# Out:
# [[1766, 53972, 1591, 428, 620, 70, 23066, 39420, 3168, 83, 5501, 1]]

# %%
(((y_test-pred/y_test)).mean())/100
# Out:
# 99.62564696402418
